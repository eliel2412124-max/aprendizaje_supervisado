# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('./data/titanic_clean.csv')
print(f"El dataset tiene {df.shape[0]} filas y {df.shape[1]} columnas.")
# Out:
# El dataset tiene 891 filas y 9 columnas.

# %%
df.sample(4)
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch   Fare Cabin Embarked
# 476         0       2    male  34.0      1      0  21.00   NaN        S
# 324         0       3    male   NaN      8      2  69.55   NaN        S
# 750         1       2  female   4.0      1      1  23.00   NaN        S
# 227         0       3    male  20.5      0      0   7.25   NaN        S

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
plt.figure(figsize=(12, 8))

sns.barplot(x = df['Survived'].value_counts().index, y = df['Survived'].value_counts())
plt.title('Value Counts of Survived')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize = (12, 8))

# colores para cada una de las clases
color = ['#240750', '#344C64']

sns.countplot(df, x = 'Embarked', hue = 'Survived', palette=color) 
plt.legend(title = 'Supervivencia', labels = ['No sobrevivió', 'Sí sobrevivió'])
plt.show()

# %%
plt.figure(figsize = (12, 8))

sns.histplot(df, x = 'Age', kde = True)
plt.title('Distribución de Edades')
plt.axvline(df['Age'].mean(), color = 'red')
plt.axvline(df['Age'].median(), color = 'green')
plt.axvline(df['Age'].mode()[0], color = 'black')
plt.show()

# Print the results
print(f"Media: {df['Age'].mean()}")
print(f"Mediana: {df['Age'].median()}")
print(f"Moda: {df['Age'].mode()[0]}")
# Out:
# Media: 29.69911764705882
# Mediana: 28.0
# Moda: 24.0

# %%
plt.figure(figsize = (12, 8))
sns.heatmap(df[['Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']].corr(), 
            annot=True, 
            cbar=True,  # Activar la barra de colores
            cmap='coolwarm',  # Cambiar la paleta de colores
            cbar_kws={'label': 'Nivel de correlación'})  # Etiqueta para la barra de colores
plt.title('Correlación de variables numéricas')
plt.show()

# %%
#Ejercicio 1
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/titanic_clean.csv')


plt.figure()
plt.hist(df['Age'].dropna(), bins=20)


plt.title('Distribución de edades de los pasajeros')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')


plt.show()

# %%
#Ejercico 2
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/titanic_clean.csv')

survivors_by_class = df.groupby('Pclass')['Survived'].sum()

plt.figure()
survivors_by_class.plot(kind='bar')


plt.title('Cantidad de sobrevivientes por clase')
plt.xlabel('Clase (Pclass)')
plt.ylabel('Número de sobrevivientes')

plt.show()

# %%
#Ejercicio 3
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/titanic_clean.csv')

survivors_by_sex = df.groupby('Sex')['Survived'].sum()

plt.figure()
survivors_by_sex.plot(kind='bar')

plt.title('Cantidad de sobrevivientes por género')
plt.xlabel('Género')
plt.ylabel('Número de sobrevivientes')

plt.xticks(rotation=0)
plt.show()

# %%
# Ejercicio 4
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/titanic_clean.csv')

survivors_by_embarked = df.groupby('Embarked')['Survived'].sum()

plt.figure()
survivors_by_embarked.plot(kind='bar')

plt.title('Cantidad de sobrevivientes por puerto de embarque')
plt.xlabel('Puerto de embarque')
plt.ylabel('Número de sobrevivientes')

plt.xticks(rotation=0)
plt.show()

# %%
# Ejercicio 5
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/titanic_clean.csv')

bins = [0, 5, 12, 18, 30, 60, 100]
labels = ['Infante', 'Niño', 'Adolescente', 'Joven Adulto', 'Adulto', 'Mayor']

df['AgeGroup'] = pd.cut(df['Age'], bins=bins, labels=labels)

survival_rate = df.groupby('AgeGroup')['Survived'].mean()

plt.figure()
survival_rate.plot(kind='bar')

plt.title('Tasa de supervivencia por grupo de edad')
plt.xlabel('Grupo de edad')
plt.ylabel('Tasa de supervivencia')

plt.xticks(rotation=0)
plt.show()

# %%
# Ejercicio 6
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/titanic_clean.csv')

count_by_class = df['Pclass'].value_counts().sort_index()

plt.figure()
count_by_class.plot(kind='bar')

plt.title('Cantidad de pasajeros por clase')
plt.xlabel('Clase (Pclass)')
plt.ylabel('Número de pasajeros')

plt.xticks(rotation=0)
plt.show()

# %%
# Ejercicio 7
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/titanic_clean.csv')

gender_by_class = df.groupby(['Pclass', 'Sex']).size().unstack()

plt.figure()
gender_by_class.plot(kind='bar')

plt.title('Distribución de género por clase')
plt.xlabel('Clase (Pclass)')
plt.ylabel('Cantidad')

plt.xticks(rotation=0)
plt.show()

# %%
# Ejercicio 8
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/titanic_clean.csv')

class_by_embarked = df.groupby(['Embarked', 'Pclass']).size().unstack()

plt.figure()
class_by_embarked.plot(kind='bar')

plt.title('Distribución de clase por puerto de embarque')
plt.xlabel('Puerto de embarque')
plt.ylabel('Cantidad')

plt.xticks(rotation=0)
plt.show()

# %%
# Ejercicio 9
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/titanic_clean.csv')

count_by_sex = df['Sex'].value_counts()

plt.figure()
count_by_sex.plot(kind='bar')

plt.title('Cantidad de pasajeros por género')
plt.xlabel('Género')
plt.ylabel('Número de pasajeros')

plt.xticks(rotation=0)
plt.show()

# %%
# Ejercicio 10
import pandas as pd

df = pd.read_csv('./data/titanic_clean.csv')

edad_max = df['Age'].max()
edad_min = df['Age'].min()

print('Edad máxima:', edad_max)
print('Edad mínima:', edad_min)
# Out:
# Edad máxima: 80.0
# Edad mínima: 0.42

# %%
# Ejercicio 11
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/titanic_clean.csv')

ages = df['Age'].dropna()

mean_age = ages.mean()
median_age = ages.median()
mode_age = ages.mode()[0]

plt.figure()
plt.hist(ages, bins=20)

plt.axvline(mean_age)
plt.axvline(median_age)
plt.axvline(mode_age)

plt.title('Distribución de edades con media, mediana y moda')
plt.xlabel('Edad')
plt.ylabel('Frecuencia')

plt.show()

# %%
# Ejercicio 12
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/titanic_clean.csv')

ages = df['Age'].dropna()

plt.figure()
plt.boxplot(ages, vert=True)

plt.title('Boxplot de edades')
plt.ylabel('Edad')

plt.show()

# %%
# Ejercicio 13
import pandas as pd

df = pd.read_csv('./data/titanic_clean.csv')

fare_max = df['Fare'].max()
fare_min = df['Fare'].min()

print('Tarifa máxima:', fare_max)
print('Tarifa mínima:', fare_min)
# Out:
# Tarifa máxima: 512.3292
# Tarifa mínima: 0.0

# %%
# Ejercicio 14
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/titanic_clean.csv')

fares = df['Fare'].dropna()

mean_fare = fares.mean()
median_fare = fares.median()
mode_fare = fares.mode()[0]

plt.figure()
plt.hist(fares, bins=20)

plt.axvline(mean_fare)
plt.axvline(median_fare)
plt.axvline(mode_fare)

plt.title('Distribución de tarifas con media, mediana y moda')
plt.xlabel('Tarifa')
plt.ylabel('Frecuencia')

plt.show()

# %%
# Ejercicio 15
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/titanic_clean.csv')

fares = df['Fare'].dropna()

plt.figure()
plt.boxplot(fares, vert=True)

plt.title('Boxplot de tarifas')
plt.ylabel('Tarifa')

plt.show()

# %%
# Ejercicio 16
import pandas as pd

df = pd.read_csv('./data/titanic_clean.csv')

free_passengers = df[df['Fare'] == 0]

print(free_passengers)
# Out:
#      Survived  Pclass   Sex   Age  SibSp  Parch  Fare Cabin Embarked
# 179         0       3  male  36.0      0      0   0.0   NaN        S
# 263         0       1  male  40.0      0      0   0.0   B94        S
# 271         1       3  male  25.0      0      0   0.0   NaN        S
# 277         0       2  male   NaN      0      0   0.0   NaN        S
# 302         0       3  male  19.0      0      0   0.0   NaN        S
# 413         0       2  male   NaN      0      0   0.0   NaN        S
# 466         0       2  male   NaN      0      0   0.0   NaN        S
# 481         0       2  male   NaN      0      0   0.0   NaN        S
# 597         0       3  male  49.0      0      0   0.0   NaN        S
# 633         0       1  male   NaN      0      0   0.0   NaN        S
# 674         0       2  male   NaN      0      0   0.0   NaN        S
# 732         0       2  male   NaN      0      0   0.0   NaN        S
# 806         0       1  male  39.0      0      0   0.0   A36        S
# 815         0       1  male   NaN      0      0   0.0  B102        S
# 822         0       1  male  38.0      0      0   0.0   NaN        S

# %%
# Ejercicio 17
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/titanic_clean.csv')

sibsp_counts = df['SibSp'].value_counts().sort_index()

plt.figure()
sibsp_counts.plot(kind='bar')

plt.title('Cantidad de pasajeros por número de SibSp')
plt.xlabel('SibSp (Hermanos/Esposos a bordo)')
plt.ylabel('Número de pasajeros')

plt.xticks(rotation=0)
plt.show()

# %%
# Ejercicio 18
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/titanic_clean.csv')

sibsp_survival = df.groupby('SibSp')['Survived'].mean().sort_index()

plt.figure()
sibsp_survival.plot(kind='bar')

plt.title('Tasa de supervivencia por número de SibSp')
plt.xlabel('SibSp (Hermanos/Esposos a bordo)')
plt.ylabel('Tasa de supervivencia')

plt.xticks(rotation=0)
plt.show()

# %%
# Ejercicio 19
import pandas as pd

df = pd.read_csv('./data/titanic_clean.csv')

sibsp_survival_pct = df.groupby('SibSp')['Survived'].mean() * 100

print(sibsp_survival_pct.sort_index())
# Out:
# SibSp
# 0    34.539474
# 1    53.588517
# 2    46.428571
# 3    25.000000
# 4    16.666667
# 5     0.000000
# 8     0.000000
# Name: Survived, dtype: float64

# %%
# Ejercicio 20
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('./data/titanic_clean.csv')

corr = df.corr(numeric_only=True)

plt.figure()
plt.imshow(corr)

plt.xticks(range(len(corr.columns)), corr.columns, rotation=90)
plt.yticks(range(len(corr.columns)), corr.columns)

plt.title('Matriz de correlación')

plt.colorbar()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.preprocessing import QuantileTransformer
df = pd.read_csv('./data/titanic_clean.csv')

# %%
from sklearn.preprocessing import LabelEncoder

# Datos categóricos de ejemplo
animales = ['gato', 'perro', 'pez', 'gato', 'perro']

# Crear una instancia de LabelEncoder
le = LabelEncoder()

# Ajustar y transformar los datos
animales_codificados = le.fit_transform(animales)

# Mostrar los datos codificados
print(animales_codificados)

# Si deseas ver cómo se mapean las etiquetas originales
print(list(le.classes_))
# Out:
# [0 1 2 0 1]
# [np.str_('gato'), np.str_('perro'), np.str_('pez')]

# %%
label_sex = LabelEncoder()
label_embarked = LabelEncoder()

# Fit and transform on training data
df['Sex'] = label_sex.fit_transform(df['Sex'])
df['Embarked'] = label_embarked.fit_transform(df['Embarked'])

# %%
df.sample(5)
# Out:
#      Survived  Pclass  Sex    Age  SibSp  Parch     Fare Cabin  Embarked
# 326         0       3    1  61.00      0      0   6.2375   NaN         2
# 690         1       1    1  31.00      1      0  57.0000   B20         2
# 803         1       3    1   0.42      0      1   8.5167   NaN         0
# 177         0       1    0  50.00      0      0  28.7125   C49         0
# 442         0       3    1  25.00      1      0   7.7750   NaN         2

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
sns.histplot(df['Age'].dropna(), kde=True, ax=axes[0])
axes[0].set_title('Distribución de Age')
axes[0].set_xlabel('Age')
axes[0].set_ylabel('Frecuencia')

# Gráfica de la distribución de Fare
sns.histplot(df['Fare'].dropna(), kde=True, ax=axes[1])
axes[1].set_title('Distribución de Fare')
axes[1].set_xlabel('Fare')
axes[1].set_ylabel('Frecuencia')

# Mostrar las gráficas
plt.tight_layout()
plt.show()

# %%
qun_tra_age = QuantileTransformer(output_distribution = 'normal', n_quantiles=500)
qun_tra_fare = QuantileTransformer(output_distribution = 'normal', n_quantiles=500)

df['Age'] = qun_tra_age.fit_transform(df[['Age']])
df['Fare'] = qun_tra_fare.fit_transform(df[['Fare']])

# %%
mms_pclass= MinMaxScaler()
mms_sex = MinMaxScaler()
mms_age = MinMaxScaler()
mms_sibsp = MinMaxScaler()
mms_parch = MinMaxScaler()
mms_fare = MinMaxScaler()
mms_embarked = MinMaxScaler()

# Ejecutar transformaciones
df['Pclass'] = mms_pclass.fit_transform(df[['Pclass']])
df['Sex'] = mms_sex.fit_transform(df[['Sex']])
df['Age'] = mms_age.fit_transform(df[['Age']])
df['SibSp'] = mms_sibsp.fit_transform(df[['SibSp']])
df['Parch'] = mms_parch.fit_transform(df[['Parch']])
df['Fare'] = mms_fare.fit_transform(df[['Fare']])
df['Embarked'] = mms_embarked.fit_transform(df[['Embarked']])

# %%
df.to_csv('./data/titanic_procesado.csv', index=False)
